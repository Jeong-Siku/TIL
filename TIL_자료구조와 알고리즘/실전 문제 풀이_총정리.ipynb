# %%
ARRAY_LENGTH = 5  # 배열의 행과 열 크기(고정)

def replaceData(numData): # numData	2차원 정수 배열
    retData = [] # 조건에 따라서 전처리된 2차원 배열

    ###########   여기부터 코딩 (1) ---------------->
    for i in range(5):
        for j in range(5):
            if numData[i][j] < 0 :
                numData[i][j] = 0
            elif numData[i][j] > 100 :
                numData[i][j] = numData[i][j] % 100
    retData = numData


    ###########   <-------------- 여기까지 코딩 (1)

    return retData


# 2x2 크기의 배열의 최대합을 구한다.
def getMaxSum(numData): # 요구 사항에 맞춰 처리된 2차원 정수 배열
    maxSum = 0 # 최대합

    ###########   여기부터 코딩 (2) ---------------->
    for i in range(4):
        for j in range(4): 
            sum = numData[i][j]+numData[i][j+1]+numData[i+1][j]+numData[i+1][j+1]          
            maxSum= sum if sum >= maxSum else maxSum 



    ###########   <-------------- 여기까지 코딩 (2)

    return maxSum

## 전역 변수 선언 부분
numData =[] # 5x5 배열
ARRAY_LENGTH = 5 # 배열의 행과 열 크기(고정)

def main() :
        global numData

        loadData() # 2차원 배열 읽어오기

        ## 원본 출력
        print(' ----- 초기 배열 -----')
        printData()

        # 1. 데이터 치환 작업
        numData = replaceData(numData)
        print(' ----- 치환 후 배열 -----')
        printData()

        # 2. 최대 합 구하기.(2x2 크기)
        maxSum = getMaxSum(numData)
        print('최대 영역의 합: %d' % maxSum)

       
## 함수 선언 부분
def  loadData() : # 데이터 불러오기
    global numData

    ###########
    # 제공 데이터 세트 1 
    # 5x5 숫자 배열. 
    ###########
    numData = \
    [
        [ 5, 7, -5, 100, 73 ],
        [ 35, 23, 4, 190, 33 ],
        [ 49, 85, 662, 39, 81 ],
        [ 124, -59, 86, 46, 52 ],
        [ 27, 7, 8, 33, -56 ] 
    ]
    
    

def printData() :
        for i in range(0, ARRAY_LENGTH) :
                for k in range(0, ARRAY_LENGTH) :
                        try :
                                print("%5d" % numData[i][k], end='')
                        except :
                                pass
                print()
        print('--------------------------------------')

## 메인 함수 호출 ##
if __name__ == "__main__" :
    main()
# Out:
#  ----- 초기 배열 -----
#     5    7   -5  100   73
#    35   23    4  190   33
#    49   85  662   39   81
#   124  -59   86   46   52
#    27    7    8   33  -56
# --------------------------------------
#  ----- 치환 후 배열 -----
#     5    7    0  100   73
#    35   23    4   90   33
#    49   85   62   39   81
#    24    0   86   46   52
#    27    7    8   33    0
# --------------------------------------
# 최대 영역의 합: 296

# %%
# 문제풀이
# 1
retData = numData[:]
for i in range(ARRAY_LENGTH):

# %% [markdown]
# # 자료구조
# - 선형
#     - 리스트
#         - 순차 리스트(=선형 리스트) * : 배열. 빈틈이 없다. 장)공간 절약(=비용절감) 단)삽입/삭제시 오버헤드
#             실무) 날짜별 신문데이터, 소설의 연대별 기록... 시간 순서로 발생되고 저장되는 데이터!!
#         - 단순 연결 리스트 *** : Node(=Data+Link). 장)삽입/삭제시 오버헤드x 단)공간 더 필요(=비용 증가),접근이 느림
#                마지막 노드? 노드의 링크가 None, Head (첫 노드를 가리키는 변수)
#             실무) 삽입/삭제가 빈번한 데이터.
#         - 원형 연결 리스트 : 마지막 노드가 다시 Head. Link==Head
#     - 스택 : 한쪽이 막힌 파이프. FILO/LIFO. push(), pop(), top*, isStackFull(). top==SIZE-1, isStackEmpty(). top==-1
#         응용) 함수 호출 A()-->B()-->C()-->D(), 괄호 검사 <({})>
#                                             스택 : <({
#     - 큐
#         - 순차 큐 (=일반 큐) * : 양쪽이 뚫린 파이프. 개선까지 완료. enQueue(), deQueue(), front, rear, isQueueFull()?? rear==SIZE-1
#         --> 앞이 비면 땡기기. 오버헤드O
#         - 원형 큐 (=환형 큐) * : 파이프를 동그랗게 붙이기. 꼬리를 다시 머리로 잇기. %SIZE. 순차큐의 오버헤드가 개선. %SIZE. 1칸 사용못함. 초기값 0
# - 비선형
#     - 트리
#         - 이진 트리 ** : TreeNode(left, data, right)
#     - 그래프 *****
#         - 인접 행렬(2차원 배열)
#
# # 알고리즘
# - 정렬
#     - 선택 정렬 ** : 이중for문. 사이클
#     - 버블정렬
#     - 퀵정렬
# - 검색
#     - 순차검색
#     - 이진검색 *** : O(log n)
# - 재귀 ** : 코드마다 다름. 스스로 이해~~
