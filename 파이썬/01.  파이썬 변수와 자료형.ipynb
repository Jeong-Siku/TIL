# %% [markdown]
# # 파이썬이란?
# - 데이터 엔지니어링, 사이언스 및 프로그램을 만들 때 사용되는 언어
# - 다른 언어에 비해 쉽다

# %% [markdown]
# # 변수
# - 변수란 값이 저장될 수 있는 **공간**
# - 원할 때 마다 변수에 들어 있는 '값'을 언제든 바꿀 수 있다.

# %%
a = 1
print(a)
# Out:
# 1

# %%
a = 2
print(a)
# Out:
# 2

# %% [markdown]
# # comment ( 주석 )
# - 코드에서 # 으로 시작하는 부분으로써, 실행이 되지 않습니다.
# - 개발자가 어떠한 코드인지 코드상에 설명할 때 사용한다.

# %%
# 변수 a에 1을 집어 넣었습니다.
a = 1

# %% [markdown]
# # 변수에 값이 들어가는 과정
# 1. 변수의 선언 ( declaration )
# 2. 변수에 값을 할당 ( assignment )

# %%
a = 1 # 변수 a를 선언 하고, 1을 할당했다.

# %% [markdown]
# # 자료형( Data Type )
# 파이썬은 기본적으로 4가지 자료형을 가지고 있습니다.
# - `int(Integer - 정수)` : `-1, -3, 0, 1, 3, 6, 2, 4, ...`
# - `float - 실수` : `3.14, 1.123, -6.1,, 30.10238, ...`
#   - `3.0`은 **실수**
# - `str(String - 문자열)` : 문자들이 열거 되어 있으면 문자열
# - `bool(Boolean - 논리)` : 참(`True`) / 거짓(`False`)

# %%
a = 1
type(a)
# Out:
# int

# %%
a = 3.14
type(a)
# Out:
# float

# %%
# 문자열을 만들 때는 작은 따옴표('') 또는 큰 따옴표("")를 사용합니다.
a = "Hello~!~!~!~!😊"
type(a)
# Out:
# str

# %%
a = "제 이름은 소민호입니다."
type(a)
# Out:
# str

# %%
a = 3 > 2
print(a)
# Out:
# True

# %%
type(a)
# Out:
# bool

# %% [markdown]
# # variable naming (변수 이름 규칙)
# - 변수의 이름을 지을 때의 관례
# - 지금은 지키지 않아도 상관이 없는데, 나중에 이 규칙을 지키지 않으면 **오류**가 나는 경우가 있음

# %% [markdown]
# 1. `snake_case`
#   * 단어와 단어 사이를 언더바(`_`)를 이용해서 이어줍니다.
#   * `student_name`
#
# 2. `CamelCase`
#   * 단어와 단어를 이어줄 때 뒤에 오는 단어의 첫 글자를 대문자로 이어준다.
#   * `StudentName` or `studentName`
#     * 앞 글자부터 대문자 : `클래스(class)`이름을 지어줄 때
#     * 뒤 글자부터 대문자 : 변수의 이름을 지을 때
#
# 3. `kebab-case`
#   * 단어와 단어 사이를 하이푼(`-`)을 이용해서 이어줍니다.
#   * `student-name`
#
# **파이썬의 관례상 변수의 이름은  `snake_case`, 클래스의 이름은 `CamelCase`**

# %%
studentName = "minho" # CamelCase
student_name = "minho" # snake_case. 파이썬에서 변수를 만들 때 주로 사용합니다.

# %%
학생이름 = "민호"
print(학생이름)
# Out:
# 민호

# %% [markdown]
# 한글로도 변수의 이름은 지어 줄 수 있으나. **굉장히 비추**

# %% [markdown]
# # 상수
# - 변수는 변하는 수.
# - 변하지 않는 수. 파이썬에는 상수가 없어요...
#   - 변수에 특별한 효과를 줘서 상수로 사람이 인지하게끔 합니다.

# %%
_jumin_number = "880129-1xxxxxx"
JUMIN_NUMBER  = "880129-1xxxxxx"

# %%
a = 3
a # 변수에 들어 있는 값을 확인. 제일 마지막에 적힌 변수만
# Out:
# 3

# %%
print(a) # 직접적으로 출력을 하겠다
# Out:
# 3

# %%
a
a
a
a
# Out:
# 3

# %%
print(a)
print(a)
print(a)
print(a)
# Out:
# 3
# 3
# 3
# 3
