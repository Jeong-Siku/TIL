# %% [markdown]
# # 함수(function)
# - (재사용 할)코드의 묶음

# %%
# 성적계산기를 만들어 보자!

score = 60

if score >= 90:
  print("A")
elif score >= 80:
  print("B")
elif score >= 70:
  print("C")
elif score >= 60:
  print("D")
else:
  print("F")
# Out:
# D

# %%
# 두 번째 사람에 대한 처리
score = 85

if score >= 90:
  print("A")
elif score >= 80:
  print("B")
elif score >= 70:
  print("C")
elif score >= 60:
  print("D")
else:
  print("F")
# Out:
# B

# %% [markdown]
# 3일 뒤...

# %%
score = 95

if score >= 90:
  print("A")
elif score >= 80:
  print("B")
elif score >= 70:
  print("C")
elif score >= 60:
  print("D")
else:
  print("F")
# Out:
# A

# %% [markdown]
# 매번 ctrl + c, v를 하면서 그때 그때 마다 코드를 작성하는게 옳은 방법일까?

# %%
# 반복적인 기능을 하는 코드 뭉치(code context)를 정의해 놓고 필요 할 때 마다 사용
# 정의 : def
# 사용(호출) : call

# print_grade라는 함수를 정의
def print_grade(score):
  if score >= 90:
    print("A")
  elif score >= 80:
    print("B")
  elif score >=70 :
    print("C")
  elif score >= 60:
    print("D")
  else:
    print("F")

# print_grade 함수를 호출
print_grade(80)
# Out:
# B

# %%
print_grade(90)
print_grade(75)
print_grade(100)
print_grade(60)
# Out:
# A
# C
# A
# D

# %%
print("파이썬에서 기본적으로 print라는 함수를 제공하고 있었다.")
# Out:
# 파이썬에서 기본적으로 print라는 함수를 제공하고 있었다.

# %%
print_grade
# Out:
# <function __main__.print_grade>

# %% [markdown]
# # 함수의 정의 방법
# ```python
# def <function_name>([paramter1, parameter2, ...]):
#   ...
#   code context
#   ...
# ```
# * 파라미터(Parameter) : 함수를 **정의**할 때 호출하는 곳에서 입력해주는 **데이터를 저장할 변수**
# * 아규먼트(Argument) : 함수를 호출하는 곳에서 함수에 넣어주는 **데이터**
#
# 파라미터의 변수명과 아규먼트의 변수명은 항상 같아야 할가요?
# - No!

# %%
my_score = 90
print_grade(my_score) # print_grade(score = my_score)
# Out:
# A

# %%
# 1. Parameter X, Return X

def foo(): # Paramter가 없음!
  print("Here is foo")
  print("Paramter X, Return X")

# Paramter가 없으니까 Argument를 안 넣어 준다.
foo()
# Out:
# Here is foo
# Paramter X, Return X

# %%
# 2. Paramter O, Return X
#   대표적으로 print가 있다.

def goo(num1, num2): # num1, num2 Parameter가 있다.
  if num1 + num2 > 10:
    print("BIG")
  else:
    print("SMALL")

goo(1, 2) # 1, 2는 goo 함수의 Argument가 된다.
goo(10, 20) # 10, 20은 goo 함수의 Argument가 된다.
# Out:
# SMALL
# BIG

# %%
# return이 없다?
result = goo(10, 20) # goo의 결과는 아무것도 없다!
print(result) # None 출력
# Out:
# BIG
# None

# %%
result = print("안녕하세요 반갑습니다.")
print(result)
# Out:
# 안녕하세요 반갑습니다.
# None

# %%
# 3. Parameter X, Return O
def moo(): # Parameter가 없음!
  print("moo is called")
  lst = [1, 3, 5, 7, 9]
total = sum(lst)

  return total  # return 값이 존재한다.

moo_result = moo() # 함수 moo는 값을 반환(return)한다. 따라서 리턴값을 변수로 받아 낼 수 있다.
print(moo_result)
# Out:
# moo is called
# 2500

# %%
# 4. Parameter O, Return O
def hoo(num1, num2):
  print("hoo is called")
  return num1 + num2 # num1과 num2를 더해서 그 결과를 리턴

a = 10
b = 20
hoo_result = hoo(a, b)

print(hoo_result)
# Out:
# hoo is called
# 30

# %% [markdown]
# # 파라미터를 정의하는 3가지 방법
# 1. `default parameter` ★★★★★
# 2. 여러 아규먼트를 한꺼번에 묶어서 동시에 포함 시키기 ★★★
#   * `*args`
#   * `print` 함수에서 사용되고 있음
# 3. 여러 아규먼트를 `dict` 형태로 받기 ★★
#   * `**kwargs`
#   * 직접 만들 일은 생각보다 만히 없으나, 이미 만들어진 것을 사용할 때 주로 사용된다.

# %% [markdown]
# ## Default Parameter
# - 함수를 호출 할 때 Argument를 넣어주지 않아도 기본적으로 파라미터가 가지고 있어야 할 값을 지정

# %%
def noo(a, b, c):
  print(a, b, c)

noo("Hello", 30, 5.1212112)
# Out:
# Hello 30 5.1212112

# %% [markdown]
# `noo` 함수는 Parameter가 3개!
#   - `noo`를 호출하기 위해서는 Argument가 3개가 되어야 한다

# %%
noo(10, 20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-4a0694526a33> in <module>()
# ----> 1 noo(10, 20)
#
# TypeError: noo() missing 1 required positional argument: 'c'

# %%
# 파라미터 c에 기본적으로 30을 넣어준다
# default parameter
def koo(a, b, c=30):
  print(a, b, c)

koo(10, 20) # 파라미터 c의 기본값이 30으로 지정 되었기 때문에 c에 대한 Argument를 넣지 않아도 koo가 호출이 된다.
# Out:
# 10 20 30

# %%
koo(10, 20, "Hello") # c의 위치에 "Hello"가 들어갔으니까 30이 아닌 "Hello"가 들어간다.
# Out:
# 10 20 Hello

# %% [markdown]
# 잘못된 default parameter 설정

# %%
def roo(a, b=20, c):
  print(a, b, c)

roo(10, 30) # 30이 b에 들어갈지, c에 들어갈지...?
# Out:
#   File "<ipython-input-34-0db618ea52fd>", line 1
#     def roo(a, b=20, c):
#            ^
# SyntaxError: non-default argument follows default argument

# %% [markdown]
# default parameter는 항상 오른쪽부터 채워야 한다.

# %%
def woo(a, b=20, c=30):
  print(a, b, c)

# woo의 default parameter가 2개니까 argument를 1개만 집어 넣어도 호출 가능
woo("Hello")
# Out:
# Hello 20 30

# %% [markdown]
# `default parameter`는 사용자가 넣어주지 않아도 기본적으로 세팅 되어야 할 옵션이 있을 때 사용

# %% [markdown]
# # `*args`
# - 함수를 정의하면서 Argument가 `n`개가 들어 갈 수 있다!
# - `*`을 `asterisk`라고 함

# %%
# 2개의 파라미터를 직접 정의
def add_ver1(a, b):
  total = a + b
  print(total)

add_ver1(10, 20)
# Out:
# 30

# %%
# 3개의 파라미터를 직접 정의
def add_ver2(a, b, c):
  total = a + b + c
  print(total)

add_ver2(10, 20, 30)
# Out:
# 60

# %% [markdown]
# `N`개의 Argument를 받아서 더하고 싶다? `*args`

# %%
# 파라미터를 *args로 만들면 입력되는 Argument의 튜플을 생성한다.
def add_ver3(*args):
  print(args)
  total = sum(args)
  print(total)

add_ver3(1,2,3,5,6,7,8,9,10,11,12,101)
# Out:
# (1, 2, 3, 5, 6, 7, 8, 9, 10, 11, 12, 101)
# 175

# %%
# print 함수도 출력할 값을 *args로 받게 된다.
print("hello", "hi", 1, 2, 3, 4, 5, 6, 1, 2, 3)
# Out:
# hello hi 1 2 3 4 5 6 1 2 3

# %% [markdown]
# 하나의 함수에서 여러 개의 `*args`를 사용 할 수 있을까? - NO!

# %%
# Error
# def qoo(*args1, *args2):
#   print(args1, args2)

# %% [markdown]
# `Positional Argument`와 `*args` 같이 사용하기
# - Positional Argument는 Parameter의 위치에 맞게 들어가는 Argument

# %%
def qoo(a, b, *args):
  print(a)
  print(b)
  print(args)

qoo(1, 2, 3,4,5,6,7,8,9)
# Out:
# 1
# 2
# (3, 4, 5, 6, 7, 8, 9)

# %%
# *args가 가운데에 위치할 수 있을까요?
def eoo(a, *args, b):
  print(a)
  print(args)
  print(b)

# %%
eoo(1, 2,3,4,5,6,7,8, 9)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-16eb440db557> in <module>()
# ----> 1 eoo(1, 2,3,4,5,6,7,8, 9)
#
# TypeError: eoo() missing 1 required keyword-only argument: 'b'

# %%
# keyword Argument 활용해서 b에 값을 명시적으로 넣어주기
eoo(1, 2,3,4,5,6,7,8,9, b="Hello")
# Out:
# 1
# (2, 3, 4, 5, 6, 7, 8, 9)
# Hello

# %% [markdown]
# ## Keyword Argument?
# - 파라미터에 값을 넣어줄 때 파라미터의 변수명을 **직접** 기입하는 것

# %%
def too(a, b, c):
  print(a, b, c)

too(10, 20, 30) # 파라미터 a, b, c의 순서에 맞춰서 아규먼트를 집어 넣는 것 - Positional Argument
too(b=20, c=30, a=10) # 파라미터의 이름을 기입해서 아규먼트를 집어 넣는 것 - Keyword Argument
too(10, c=30, b=20) # 10은 Positional Argument로 a에 들어가고, 나머지 b,c는 keyword argument로 들어간다.
# Out:
# 10 20 30
# 10 20 30
# 10 20 30

# %% [markdown]
# ## `**kwargs`
# - 직접 정의해서 만드는 경우는 많이 없으나, 알아두기만 해도 좋다
# - 입력된 Keyword Argument들을 `dict`로 정리

# %%
def yoo(a, b, **kwargs):
  print(a)
  print(b)
  print(kwargs)

# %%
yoo(10, 20, c=30, hihi=40, byebye=50)
# Out:
# 10
# 20
# {'c': 30, 'hihi': 40, 'byebye': 50}

# %% [markdown]
# keyword argument의 변수명이 `Key`로, 값이 `value`로 들어간다.

# %%
def aoo(a, b, *args, **kwargs):
  print(a)
  print(b)
  print(args)
  print(kwargs)

# %%
aoo(1,2,3,4,5,6,7,8)
# Out:
# 1
# 2
# (3, 4, 5, 6, 7, 8)
# {}

# %%
aoo(1,2,3,4,5,6,7,8,c="hi", d="bye")
# Out:
# 1
# 2
# (3, 4, 5, 6, 7, 8)
# {'c': 'hi', 'd': 'bye'}

# %%
aoo(1,2,3, a=10, 5,6,7) # keyword argument도 항상 오른쪽 부터 채운다
# Out:
#   File "<ipython-input-63-1950ece20a30>", line 1
#     aoo(1,2,3, a=10, 5,6,7) # keyword argument도 항상 오른쪽 부터 채운다
#                     ^
# SyntaxError: positional argument follows keyword argument

# %%
# default parameter를 쓰는 이유가 없다!
def boo(a, b, c=30, d=40, *args, **kwargs): # 이렇게는 잘 쓰지 않는다.
  print(a)
  print(b)
  print(c)
  print(d)
  print(args)
  print(kwargs)

# %%
boo(1,2,3,4,5,6,7, e=10, f=30)
# Out:
# 1
# 2
# 30
# 40
# (3, 4, 5, 6, 7)
# {'e': 10, 'f': 30}

# %%
boo(1,2,3,4,5,6,7, e=10, f=30, c="hi", d="Bye")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-bb938e30bd08> in <module>()
# ----> 1 boo(1,2,3,4,5,6,7, e=10, f=30, c="hi", d="Bye")
#
# TypeError: boo() got multiple values for argument 'c'

# %%
def coo(a, b, *args,  c=30, d=40, **kwargs): # default parameter를 **kwargs보다 앞 쪽에 배치
  print(a)
  print(b)
  print(c)
  print(d)
  print(args)
  print(kwargs)

# %%
coo(1,2,3,4,5,6,7,8, e="hihi", f="byebye")
# Out:
# 1
# 2
# 30
# 40
# (3, 4, 5, 6, 7, 8)
# {'e': 'hihi', 'f': 'byebye'}

# %% [markdown]
# # 람다 함수
# - 삼항연산 또는 컴프리헨션과 흡사하게 만들어지는 함수
# - 한줄 짜리 간단한 함수를 만들 때 사용
# - 1회용 함수를 만들 때 많이 사용

# %%
def add(num1, num2):
  return num1 + num2

add(1, 2)
# Out:
# 3

# %%
add_lambda = lambda num1, num2 : num1 + num2
add_lambda(1, 2)
# Out:
# 3

# %% [markdown]
# 1. 람다 함수는 아주 간단한 파라미터가 있고, 일반적으로 리턴이 있는 함수를 만들 때 사용 한다.
# 2. 1회성으로 사용하는 아주 간단한 함수를 만들 때 사용
#
# ```
# x라는 정수를 받아서 x의 제곱을 리턴하는 람다 함수 만들어 보기
# ```

# %%
square = lambda x : x ** 2
square(5)
# Out:
# 25

# %% [markdown]
# # Scope 범위
# - 제어문(`if, for, while 등`) 및 함수의 내부에서 선언되는 변수와 밖에서 선언되는 변수의 **사용범위(scope)**가 다르다
#   - 파이썬에서는 제어문은 해당이 안된다.
# - `global`(전역), `local`(지역)

# %%
# 전역 변수 - 어디에서든 접근이 가능
gv = 10

def foo():
  print(gv)

foo()
# Out:
# 10

# %%
# 전역변수 gv
gv = 10

# 함수 내부에서 만들어진 변수를 해당 함수의 지역 변수라 한다.
def goo():
  # 지역 gv
  gv = 100
  print(gv)

goo()
print(gv)
# Out:
# 100
# 10

# %% [markdown]
# 전역 변수와 지역 변수의 이름이 같으면 변수의 의미가 애매모호 해줄 수 있다.
#
# 함수 내에서 명시적으로 전역 변수를 사용할 수 있게 해주면 된다.

# %%
gv = 10

def hoo():
  # 명시적으로 gv를 전역 영역에 있는 변수로 설정한다.
  global gv
  gv = 100
  print(gv)

hoo()
print(gv)
# Out:
# 100
# 100

# %%
# 지역 변수는 해당 변수가 만들어진 code context를 벗어나면 사라진다.
def moo():
  lv_moo = 10
  print(lv_moo)

moo()
print(lv_moo)
# Out:
# 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-39685cc7e9db> in <module>()
#       5
#       6 moo()
# ----> 7 print(lv_moo)
#
# NameError: name 'lv_moo' is not defined

# %% [markdown]
# - 함수 밖에서 만들어진 전역 변수는 어디에서든 사용이 가능하다.
# - 함수 내부에서 만들어진 지역 변수는 함수 내에서만 사용이 가능하다.
#   - 지역 변수에 해당하는 것 : 함수 내에서 선언된 변수, 파라미터

# %% [markdown]
# # 지역 함수(내부 함수)
# - 함수 내부에 또 다른 함수가 정의 되는 것

# %%
def outer(a, b):
  print("Here is Outer")

  def inner(c, d):
    print("Here is inner")
    return c + d

  return inner(a, b)

# inner 함수의 호출 시점 : outer의 호출 시점
# outer가 호출이 되어야 inner가 호출이 된다.

inner_result = outer(10, 20)
print(inner_result)
# Out:
# Here is Outer
# Here is inner
# 30

# %%
# outer에서 만들어진 함수를 당장 호출하는게 아니고, 내가 원하는 시점에 호출하고 싶으면?
def outer(a, b):
  print('Here is Outer')

  def inner():
    print("Here is Inner")
    return a + b

  return inner # 함수 자체를 리턴

# %%
# 값을 미리 받아 놓고 (a, b)
inner_func = outer(10, 20)
inner_func
# Out:
# Here is Outer
# <function __main__.outer.<locals>.inner>

# %%
# 원할 때 계산 수행
inner_func()
# Out:
# Here is Inner
# 30

# %% [markdown]
# # Callback Function ★★★
# - 함수의 Argument로 함수가 넘어가는 것
# - 함수 Argument를 받는 Parameter를 Callback Function 이라고 한다.

# %%
# 값 두개를 받아서 제곱을 한 후 더하거나, 빼는 함수를 만들고 싶어요!

# foo : 값 두개를 받아서 제곱한 다음 "어떠한 연산"을 하는 함수
# 추상적이다 한다(abstract)

def foo(callback, a, b):
  a **= 2 # a = a ** 2
  b **= 2

  return callback(a, b)

def add_func(num1, num2):
  return num1 + num2

def sub_func(num1, num2):
  return num1 - num2

# %%
foo(sub_func, 100, 200)
# Out:
# 50000

# %%
foo(add_func, 200, 300)
# Out:
# 130000

# %%
foo(lambda a, b : a * b, 100, 200)
# Out:
# 400000000

# %% [markdown]
# # Decorator
# 코드를 바꾸지 않고 기능을 추가하거나 수정하고 싶을 때 사용하는 문법

# %%
def bus(name):
  print("카드를 찍고 타야한다.")
  print(f"{name}이 버스를 탔습니다.")
  print("카드를 찍고 내립니다.")

def subway(name):
  print("카드를 찍고 타야한다.")
  print(f"{name}이 지하철를 탔습니다.")
  print("카드를 찍고 내립니다.")

# %%
# 카드를 찍은 다음 타고, 찍은 다음 내리는 메인 로직을 꾸며주는 부가적인 로직
def tag_card(callback): # 수행할 메인 로직 (버스나, 지하철을 타는 로직)
  # 메인 로직을 꾸며줄 함수를 작성.
  # 메인 로직을 꾸며주는 로직으로 감싸야 한다.

  # 메인 로직을 꾸며내면서 실행. 메인로직에 들어가는 Argument들은??
  # wrapper 함수에서 책임을 지어준다.( wrapper 함수가 대신 받아줌 )
  def wrapper(*args, **kwargs):
    print("카드를 찍고 탑니다.")
    callback(*args, **kwargs) # *를 붙여서 Argument를 넣어주면 알아서 다 풀려서 들어간다.
    print("카드를 찍고 내립니다.")

  return wrapper

# %%
# Decorator
@tag_card
def bus(fee):
  ###
  # 어떠한 복잡한 로직이 있더라도 메인 로직만 신경 쓰면 된다.
  ###
  print(f"{fee}를 내고 버스를 탑니다.")

bus(1250)
# Out:
# 카드를 찍고 탑니다.
# 1250를 내고 버스를 탑니다.
# 카드를 찍고 내립니다.

# %%
def subway(fee):
  print(f"{fee}를 내고 지하철을 탑니다.")
wrapper = tag_card(subway)
wrapper(1250)
# Out:
# 카드를 찍고 탑니다.
# 1250를 내고 지하철을 탑니다.
# 카드를 찍고 내립니다.
